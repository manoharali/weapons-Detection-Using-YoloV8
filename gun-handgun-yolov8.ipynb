# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.6/613.6 kB 9.9 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import shutil
import random
import tqdm
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.169 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 15.6 GB RAM, 4974.3/8062.4 GB disk)

# %%
# !cp -r /kaggle/input/gun-and-hangun-dataset/Gun_handGun /kaggle/working/

# %%
# !rm /kaggle/working/handGun_gun.yaml

# %%
# !cp -r /kaggle/input/yamlfilehandgun/handGun_gun.yaml /kaggle/working/

# %%
# !yolo task=detect mode=train model=yolov8s.pt data="/kaggle/working/handGun_gun.yaml" epochs=100 imgsz=640 batch=16 project="/kaggle/working/" name=output100GunHandGun lrf=0.0005 momentum= 0.9
# Out:
# Ultralytics YOLOv8.0.169 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# ...

# %%
# Use the ! command to create a zip file
#!zip -r /kaggle/working/output100GunHandGun3.zip /kaggle/working/output100GunHandGun3
# Out:
#   adding: kaggle/working/output100GunHandGun3/ (stored 0%)
#   adding: kaggle/working/output100GunHandGun3/train_batch0.jpg (deflated 4%)
#   adding: kaggle/working/output100GunHandGun3/events.out.tfevents.1693757254.fda0b00b91ad.367.0 (deflated 74%)
#   adding: kaggle/working/output100GunHandGun3/train_batch22321.jpg (deflated 13%)
#   adding: kaggle/working/output100GunHandGun3/results.csv (deflated 85%)
#   adding: kaggle/working/output100GunHandGun3/train_batch22322.jpg (deflated 23%)
#   adding: kaggle/working/output100GunHandGun3/results.png (deflated 8%)
#   adding: kaggle/working/output100GunHandGun3/labels.jpg (deflated 17%)
#   adding: kaggle/working/output100GunHandGun3/train_batch2.jpg (deflated 5%)
#   adding: kaggle/working/output100GunHandGun3/labels_correlogram.jpg (deflated 40%)
#   adding: kaggle/working/output100GunHandGun3/train_batch1.jpg (deflated 7%)
#   adding: kaggle/working/output100GunHandGun3/train_batch22320.jpg (deflated 12%)
# ...

# %%
from ultralytics import YOLO
model = YOLO('/kaggle/working/output100GunHandGun3/weights/best.pt')

# %%
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.169 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients
# val: Scanning /kaggle/working/Gun_handGun/labels/val.cache... 156 images, 0 backgrounds, 0 corrupt: 100%|██████████| 156/156 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.18it/s]
#                    all        156        206      0.865      0.751       0.83      0.542
#                    Gun        156        100       0.84        0.7      0.788      0.518
#                HandGun        156        106       0.89      0.802      0.873      0.567
# Speed: 1.6ms preprocess, 7.2ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to runs/detect/val2
# array([    0.54245,     0.51832,     0.56659])
