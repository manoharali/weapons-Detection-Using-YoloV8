# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/e-100-result/kaggle/working/yolov5/runs/train/exp/PR_curve.png
# /kaggle/input/e-100-result/kaggle/working/yolov5/runs/train/exp/P_curve.png
# /kaggle/input/e-100-result/kaggle/working/yolov5/runs/train/exp/events.out.tfevents.1693204598.2349da2144e7.90.0
# /kaggle/input/e-100-result/kaggle/working/yolov5/runs/train/exp/val_batch0_pred.jpg
# /kaggle/input/e-100-result/kaggle/working/yolov5/runs/train/exp/F1_curve.png
# /kaggle/input/e-100-result/kaggle/working/yolov5/runs/train/exp/confusion_matrix.png
# /kaggle/input/e-100-result/kaggle/working/yolov5/runs/train/exp/results.png
# /kaggle/input/e-100-result/kaggle/working/yolov5/runs/train/exp/hyp.yaml
# /kaggle/input/e-100-result/kaggle/working/yolov5/runs/train/exp/val_batch1_pred.jpg
# /kaggle/input/e-100-result/kaggle/working/yolov5/runs/train/exp/val_batch2_labels.jpg
# /kaggle/input/e-100-result/kaggle/working/yolov5/runs/train/exp/R_curve.png
# ...

# %%
# !cp -r /kaggle/input/weapons-detection-dataset/weapons_data /kaggle/working/

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-212-g9974d51 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 15.6 GB RAM, 4959.0/8062.4 GB disk)

# %%
# !cp -r /kaggle/input/yaml-file/dataset.yaml /kaggle/working/yolov5/data

# %%
#!python train.py --img 640 --batch 16 --epochs 100 --data dataset.yaml --weights yolov5s.pt --cache
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# ...

# %%
#!zip -r /kaggle/working/exp_e100.zip /kaggle/working/yolov5/runs/train/exp
# Out:
# 	zip warning: name not matched: /kaggle/working/yolov5/runs/train/exp
#
# zip error: Nothing to do! (try: zip -r /kaggle/working/exp_e100.zip . -i /kaggle/working/yolov5/runs/train/exp)

# %%
# !cp -r /kaggle/input/e-100-result/kaggle/working/yolov5/runs /kaggle/working/yolov5

# %%
# !mv /kaggle/input/testing-videos-different /kaggle/working/
# Out:
# mv: cannot remove '/kaggle/input/testing-videos-different/guntesting.mp4': Read-only file system
# mv: cannot remove '/kaggle/input/testing-videos-different/threeobject.mp4': Read-only file system
# mv: cannot remove '/kaggle/input/testing-videos-different/knifearmy.mp4': Read-only file system
# mv: cannot remove '/kaggle/input/testing-videos-different/knifeandgun.mp4': Read-only file system
# mv: cannot remove '/kaggle/input/testing-videos-different/handgun.mp4': Read-only file system
# mv: cannot remove '/kaggle/input/testing-videos-different/knifeattackcar.mp4': Read-only file system

# %%
# !python detect.py --source /kaggle/working/testing-videos-different/threeobject.mp4 --weights /kaggle/working/yolov5/runs/train/exp/weights/best.pt
# Out:
# detect: weights=['/kaggle/working/yolov5/runs/train/exp/weights/best.pt'], source=/kaggle/working/testing-videos-different/threeobject.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-212-g9974d51 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/2350) /kaggle/working/testing-videos-different/threeobject.mp4: 384x640 1 HandGun, 50.7ms
# video 1/1 (2/2350) /kaggle/working/testing-videos-different/threeobject.mp4: 384x640 2 HandGuns, 7.5ms
# ...

# %%
# !zip -r /kaggle/working/yolov5.zip /kaggle/working/yolov5
# Out:
#   adding: kaggle/working/yolov5/ (stored 0%)
#   adding: kaggle/working/yolov5/CONTRIBUTING.md (deflated 56%)
#   adding: kaggle/working/yolov5/.github/ (stored 0%)
#   adding: kaggle/working/yolov5/.github/PULL_REQUEST_TEMPLATE.md (deflated 40%)
#   adding: kaggle/working/yolov5/.github/workflows/ (stored 0%)
#   adding: kaggle/working/yolov5/.github/workflows/links.yml (deflated 57%)
#   adding: kaggle/working/yolov5/.github/workflows/stale.yml (deflated 58%)
#   adding: kaggle/working/yolov5/.github/workflows/ci-testing.yml (deflated 72%)
#   adding: kaggle/working/yolov5/.github/workflows/codeql-analysis.yml (deflated 51%)
#   adding: kaggle/working/yolov5/.github/workflows/greetings.yml (deflated 61%)
#   adding: kaggle/working/yolov5/.github/workflows/docker.yml (deflated 67%)
#   adding: kaggle/working/yolov5/.github/workflows/translate-readme.yml (deflated 47%)
#   adding: kaggle/working/yolov5/.github/dependabot.yml (deflated 60%)
# ...
